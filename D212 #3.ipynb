# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import warnings
warnings.filterwarnings('ignore')

data=pd.read_csv(r'C:\Users\abram\Downloads\teleco_market_basket.csv')
data.head(5)
# Out:
#                                   Item01                            Item02  \
# 0                                    NaN                               NaN
# 1           Logitech M510 Wireless mouse                         HP 63 Ink
# 2                                    NaN                               NaN
# 3  Apple Lightning to Digital AV Adapter  TP-Link AC1750 Smart WiFi Router
# 4                                    NaN                               NaN
#
#          Item03                      Item04                     Item05  \
# 0           NaN                         NaN                        NaN
# 1     HP 65 ink  nonda USB C to USB Adapter  10ft iPHone Charger Cable
# 2           NaN                         NaN                        NaN
# 3  Apple Pencil                         NaN                        NaN
# 4           NaN                         NaN                        NaN
#
#          Item06                        Item07  \
# ...

# %%
data.shape
# Out:
# (15002, 20)

# %%
data=data.dropna(how='all')

data.shape
# Out:
# (7501, 20)

# %%
from mlxtend.preprocessing import TransactionEncoder

rows =[]
for i in range (0, 7501):
    rows.append([str(data.values[i,j])
for j in range (0,20)])

# %%
DE= TransactionEncoder()
array= DE.fit(rows).transform(rows)

transaction= pd.DataFrame(array, columns= DE.columns_)
transaction
# Out:
#       10ft iPHone Charger Cable  10ft iPHone Charger Cable 2 Pack  \
# 0                          True                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
# ...                         ...                               ...
# 7496                      False                             False
# 7497                      False                             False
# 7498                      False                             False
# 7499                      False                             False
# 7500                      False                             False
#
#       3 pack Nylon Braided Lightning Cable  3A USB Type C Cable 3 pack 6FT  \
# 0                                    False                            True
# ...

# %%
cleaned_data = transaction.drop(['nan'], axis=1)
cleaned_data.shape
# Out:
# (7501, 119)

# %%
cleaned_data.to_csv(r'C:\Users\abram\Downloads\cleanedMBA.csv',encoding='utf-8')

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
count=cleaned_data.loc[:,:].sum()
pop_item=count.sort_values(0, ascending=False).head(5)
pop_item=pop_item.to_frame()
pop_item=pop_item.reset_index()
pop_item=pop_item.rename(columns={'index':'Products',0:'count'})

plt.rcParams['figure.figsize']=(10,6)
ax=pop_item.plot.barh(x='Products', y='count')
plt.title('Popular Inventory Items')
plt.gca().invert_yaxis()

# %%
rules=apriori(cleaned_data, min_support=.02, use_colnames = True )
rules.head()
# Out:
#     support                                 itemsets
# 0  0.050527       (10ft iPHone Charger Cable 2 Pack)
# 1  0.042528         (3A USB Type C Cable 3 pack 6FT)
# 2  0.029463           (Anker 2-in-1 USB Card Reader)
# 3  0.068391            (Anker USB C to HDMI Adapter)
# 4  0.087188  (Apple Lightning to Digital AV Adapter)

# %%
rul_table=association_rules(rules, metric='lift', min_threshold=1)
rul_table.head(20)
# Out:
#                                 antecedents  \
# 0        (10ft iPHone Charger Cable 2 Pack)
# 1          (Dust-Off Compressed Gas 2 pack)
# 2          (Dust-Off Compressed Gas 2 pack)
# 3             (Anker USB C to HDMI Adapter)
# 4        (VIVO Dual LCD Monitor Desk mount)
# 5             (Anker USB C to HDMI Adapter)
# 6                            (Apple Pencil)
# 7   (Apple Lightning to Digital AV Adapter)
# 8          (Dust-Off Compressed Gas 2 pack)
# 9   (Apple Lightning to Digital AV Adapter)
# 10                  (USB 2.0 Printer cable)
# 11  (Apple Lightning to Digital AV Adapter)
# 12       (VIVO Dual LCD Monitor Desk mount)
# 13  (Apple Lightning to Digital AV Adapter)
# 14                           (Apple Pencil)
# 15              (Apple USB-C Charger cable)
# 16                           (Apple Pencil)
# 17         (Dust-Off Compressed Gas 2 pack)
# 18                           (Apple Pencil)
# 19                              (HP 61 ink)
#
# ...

# %%
top3_conf = rul_table.sort_values('confidence', ascending = False).head(3)
top3_conf
# Out:
#                               antecedents                       consequents  \
# 0      (10ft iPHone Charger Cable 2 Pack)  (Dust-Off Compressed Gas 2 pack)
# 36  (FEIYOLD Blue light Blocking Glasses)  (Dust-Off Compressed Gas 2 pack)
# 52              (SanDisk Ultra 64GB card)  (Dust-Off Compressed Gas 2 pack)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.050527            0.238368  0.023064    0.456464  1.914955
# 36            0.065858            0.238368  0.027596    0.419028  1.757904
# 52            0.098254            0.238368  0.040928    0.416554  1.747522
#
#     leverage  conviction  zhangs_metric
# 0   0.011020    1.401255       0.503221
# 36  0.011898    1.310962       0.461536
# 52  0.017507    1.305401       0.474369

# %%
top3_lift = rul_table.sort_values('lift', ascending = False).head(3)
top3_lift
# Out:
#                               antecedents                         consequents  \
# 85     (VIVO Dual LCD Monitor Desk mount)           (SanDisk Ultra 64GB card)
# 84              (SanDisk Ultra 64GB card)  (VIVO Dual LCD Monitor Desk mount)
# 64  (FEIYOLD Blue light Blocking Glasses)  (VIVO Dual LCD Monitor Desk mount)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 85            0.174110            0.098254  0.039195    0.225115  2.291162
# 84            0.098254            0.174110  0.039195    0.398915  2.291162
# 64            0.065858            0.174110  0.022930    0.348178  1.999758
#
#     leverage  conviction  zhangs_metric
# 85  0.022088    1.163716       0.682343
# 84  0.022088    1.373997       0.624943
# 64  0.011464    1.267048       0.535186

# %%
top3_support = rul_table.sort_values('support', ascending = False).head(3)
top3_support
# Out:
#                            antecedents                         consequents  \
# 62    (Dust-Off Compressed Gas 2 pack)  (VIVO Dual LCD Monitor Desk mount)
# 63  (VIVO Dual LCD Monitor Desk mount)    (Dust-Off Compressed Gas 2 pack)
# 41    (Dust-Off Compressed Gas 2 pack)                         (HP 61 ink)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 62            0.238368            0.174110  0.059725    0.250559  1.439085
# 63            0.174110            0.238368  0.059725    0.343032  1.439085
# 41            0.238368            0.163845  0.052660    0.220917  1.348332
#
#     leverage  conviction  zhangs_metric
# 62  0.018223    1.102008       0.400606
# 63  0.018223    1.159314       0.369437
# 41  0.013604    1.073256       0.339197
